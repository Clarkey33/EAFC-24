# %%
import pandas as pd
import numpy as np

# %%
#load dataset
dfPlayersMen= pd.read_csv('male_players.csv', low_memory= False)
dfTeamsMen= pd.read_csv('male_teams.csv')

#using set option method to display all rows and columns
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %% [markdown]
# ## Data Understanding; Men Players Data

# %%
#Shape of dataframe
dfPlayersMen.shape
# Out:
# (180021, 109)

# %%
#examining the different fields
dfPlayersMen.columns.values
# Out:
# array(['player_id', 'player_url', 'fifa_version', 'fifa_update',
#        'update_as_of', 'short_name', 'long_name', 'player_positions',
#        'overall', 'potential', 'value_eur', 'wage_eur', 'age', 'dob',
#        'height_cm', 'weight_kg', 'club_team_id', 'club_name', 'league_id',
#        'league_name', 'league_level', 'club_position',
#        'club_jersey_number', 'club_loaned_from', 'club_joined_date',
#        'club_contract_valid_until_year', 'nationality_id',
#        'nationality_name', 'nation_team_id', 'nation_position',
#        'nation_jersey_number', 'preferred_foot', 'weak_foot',
#        'skill_moves', 'international_reputation', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'player_traits', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
# ...

# %%
#Preview of the dataset
dfPlayersMen.head(3)
# Out:
#    player_id                             player_url  fifa_version  \
# 0     231747    /player/231747/kylian-mbappe/240002          24.0
# 1     239085   /player/239085/erling-haaland/240002          24.0
# 2     192985  /player/192985/kevin-de-bruyne/240002          24.0
#
#    fifa_update update_as_of    short_name             long_name  \
# 0          2.0   2023-09-22     K. Mbappé  Kylian Mbappé Lottin
# 1          2.0   2023-09-22    E. Haaland  Erling Braut Haaland
# 2          2.0   2023-09-22  K. De Bruyne       Kevin De Bruyne
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0           ST, LW       91         94  181500000.0  230000.0   24
# 1               ST       91         94  185000000.0  340000.0   22
# 2          CM, CAM       91         91  103000000.0  350000.0   32
#
#           dob  height_cm  weight_kg  club_team_id            club_name  \
# 0  1998-12-20        182         75          73.0  Paris Saint Germain
# ...

# %%
#from a quick preview the following features can be deleted; they provided no usefulness to the analysis
'''
['player_id', 'player_url', 'fifa_version', 'fifa_update','update_as_of','club_team_id','league_id','league_level',
       'nationality_id','nation_team_id','international_reputation','real_face']
'''
dfPlayersMen.drop(['player_id', 'player_url', 'fifa_version', 'fifa_update','update_as_of','club_team_id','league_id','league_level',
       'nationality_id','nation_team_id','international_reputation','real_face'],axis=1, inplace=True)

# %%
#checking that 12 columns were dropped.
dfPlayersMen.shape
# Out:
# (180021, 97)

# %%
#Preview of general key information about the dataframe
dfPlayersMen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180021 entries, 0 to 180020
# Data columns (total 97 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   short_name                      180021 non-null  object
#  1   long_name                       180021 non-null  object
#  2   player_positions                180021 non-null  object
#  3   overall                         180021 non-null  int64
#  4   potential                       180021 non-null  int64
#  5   value_eur                       177868 non-null  float64
#  6   wage_eur                        178173 non-null  float64
#  7   age                             180021 non-null  int64
#  8   dob                             180021 non-null  object
#  9   height_cm                       180021 non-null  int64
#  10  weight_kg                       180021 non-null  int64
#  11  club_name                       178156 non-null  object
# ...

# %%
#Check for empty values
dfPlayersMen.isna().sum()
# Out:
# short_name                             0
# long_name                              0
# player_positions                       0
# overall                                0
# potential                              0
# value_eur                           2153
# wage_eur                            1848
# age                                    0
# dob                                    0
# height_cm                              0
# weight_kg                              0
# club_name                           1865
# league_name                         1865
# club_position                       1865
# club_jersey_number                  1865
# club_loaned_from                  169298
# club_joined_date                   12588
# club_contract_valid_until_year      1865
# nationality_name                       0
# nation_position                   169923
# nation_jersey_number              169923
# preferred_foot                         0
# weak_foot                              0
# ...

# %% [markdown]
# ##### There are 97 columns; this needs to be reduced
# ##### there are 22 columns with empty values

# %%
'''
There are a couple questions players who play Ultimate Team generally want to know
1. Is this player Meta?
2. What price will this player be on the transfer Market?
3. How to build a squad with max chemistry; and probably all meta?
4. Which Meta players are cheap?
5. How to predict which promo player will be Meta?
6. Which player is in demand on the transfer market?
7. Who will make it in this team of the week? replace that with any promo?


'''
